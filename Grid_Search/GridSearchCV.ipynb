# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,dtype = int, drop_first = True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[["age","sex_male","bmi","children","smoker_yes"]]
dependent = dataset[["charges"]]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
svr_param_grid = {
    "kernel" : ["linear","rbf","poly","sigmoid"],
    "C" : [10,100,500,1000,200,3000] 
}

dt_param_grid = {
    "criterion" : ["squared_error", "friedman_mse", "absolute_error", "poisson"],
    "max_features" : [None, "sqrt","log2"] ,
    "splitter" : ["best","random"]
}

rf_param_grid = {
    "criterion" : ["squared_error", "friedman_mse", "absolute_error", "poisson"],
    "max_features" : [None, "sqrt","log2"] ,
    "n_estimators" : [10,100]
}
 
svr_grid = GridSearchCV(SVR(),svr_param_grid,refit = True,verbose = 3, n_jobs = -1)
dt_grid = GridSearchCV(DecisionTreeRegressor(),dt_param_grid,refit = True,verbose = 3, n_jobs = -1)
rf_grid = GridSearchCV(RandomForestRegressor(),rf_param_grid,refit = True,verbose = 3, n_jobs = -1)

# %%
svr_grid.fit(independent,dependent)
dt_grid.fit(independent,dependent)
rf_grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
svr_grid.best_params_
# Out:
# {'C': 1000, 'kernel': 'linear'}

# %%
dt_grid.best_params_
# Out:
# {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}

# %%
rf_grid.best_params_
# Out:
# {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}

# %%
svr_grid.cv_results_
# Out:
# {'mean_fit_time': array([0.34333005, 0.13523641, 0.11353493, 0.14880171, 0.26774311,
#         0.12534394, 0.11748881, 0.14321241, 0.66019373, 0.13025155,
#         0.13505635, 0.14797268, 1.05670171, 0.13535371, 0.16219506,
#         0.14702778, 0.45984187, 0.121523  , 0.13030853, 0.14870968,
#         3.11322646, 0.14280272, 0.2374629 , 0.15183377]),
#  'std_fit_time': array([0.10824036, 0.00560625, 0.00923474, 0.0101538 , 0.01644888,
#         0.00252294, 0.00490638, 0.00320633, 0.06652302, 0.00304119,
#         0.00426335, 0.00595514, 0.11877554, 0.00650162, 0.00740094,
#         0.00357321, 0.17797399, 0.0016132 , 0.00229509, 0.00707257,
#         0.72732969, 0.00522485, 0.01502347, 0.00572224]),
#  'mean_score_time': array([0.0913125 , 0.06956997, 0.01876988, 0.03015513, 0.01849747,
#         0.06748571, 0.01926751, 0.03114781, 0.01675968, 0.06536684,
#         0.01809578, 0.03220272, 0.01646461, 0.06664467, 0.0189497 ,
#         0.03051629, 0.01740751, 0.06600699, 0.01877265, 0.03123512,
#         0.01481776, 0.06326337, 0.01805449, 0.03053575]),
#  'std_score_time': array([0.03653839, 0.00269495, 0.00039726, 0.00170752, 0.00198269,
#         0.00194922, 0.00087651, 0.00178222, 0.00116397, 0.00178656,
#         0.00081403, 0.00186163, 0.00063364, 0.00453427, 0.00089239,
#         0.00148867, 0.00077871, 0.00203305, 0.00114843, 0.001121  ,
#         0.00286065, 0.00136746, 0.00020397, 0.00375422]),
#  'param_C': masked_array(data=[10, 10, 10, 10, 100, 100, 100, 100, 500, 500, 500, 500,
#                     1000, 1000, 1000, 1000, 200, 200, 200, 200, 3000, 3000,
#                     3000, 3000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['linear', 'rbf', 'poly', 'sigmoid', 'linear', 'rbf',
#                     'poly', 'sigmoid', 'linear', 'rbf', 'poly', 'sigmoid',
#                     'linear', 'rbf', 'poly', 'sigmoid', 'linear', 'rbf',
#                     'poly', 'sigmoid', 'linear', 'rbf', 'poly', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'poly'},
#   {'C': 10, 'kernel': 'sigmoid'},
#   {'C': 100, 'kernel': 'linear'},
#   {'C': 100, 'kernel': 'rbf'},
#   {'C': 100, 'kernel': 'poly'},
#   {'C': 100, 'kernel': 'sigmoid'},
#   {'C': 500, 'kernel': 'linear'},
#   {'C': 500, 'kernel': 'rbf'},
#   {'C': 500, 'kernel': 'poly'},
#   {'C': 500, 'kernel': 'sigmoid'},
#   {'C': 1000, 'kernel': 'linear'},
#   {'C': 1000, 'kernel': 'rbf'},
#   {'C': 1000, 'kernel': 'poly'},
#   {'C': 1000, 'kernel': 'sigmoid'},
#   {'C': 200, 'kernel': 'linear'},
#   {'C': 200, 'kernel': 'rbf'},
#   {'C': 200, 'kernel': 'poly'},
#   {'C': 200, 'kernel': 'sigmoid'},
#   {'C': 3000, 'kernel': 'linear'},
#   {'C': 3000, 'kernel': 'rbf'},
#   {'C': 3000, 'kernel': 'poly'},
#   {'C': 3000, 'kernel': 'sigmoid'}],
#  'split0_test_score': array([ -0.0189429 ,  -0.11040913,  -0.12515269,  -0.11674324,
#           0.55931297,  -0.16018172,  -0.13288461,  -0.14245497,
#           0.63213476,  -0.16091649,  -0.11199451,  -0.59087785,
#           0.7363985 ,  -0.15543029,  -0.0805268 ,  -2.04313994,
#           0.59754018,  -0.16437403,  -0.12863679,  -0.19990884,
#           0.67777829,  -0.12895834,   0.03769959, -15.56185339]),
#  'split1_test_score': array([  0.02988647,  -0.09745886,  -0.08150541,  -0.11931157,
#           0.52179776,  -0.10725311,  -0.08246084,  -0.16083065,
#           0.58719506,  -0.10351408,  -0.06145466,  -0.75976455,
#           0.6751618 ,  -0.09826656,  -0.02846903,  -2.68612062,
#           0.55753768,  -0.10642599,  -0.07846791,  -0.23183623,
#           0.62681429,  -0.07557819,   0.0984962 , -20.49890817]),
#  'split2_test_score': array([  0.02216742,  -0.07448755,  -0.11190705,  -0.08521385,
#           0.5476908 ,  -0.12343034,  -0.12921953,  -0.1175443 ,
#           0.61909515,  -0.12831196,  -0.10594393,  -0.60933322,
#           0.68000238,  -0.12372356,  -0.07337624,  -2.19456334,
#           0.58678115,  -0.12906536,  -0.12500339,  -0.18018945,
#           0.73280574,  -0.10019878,   0.0492908 , -17.09547395]),
#  'split3_test_score': array([ 3.11150946e-03, -9.95972567e-02, -1.31602268e-01, -1.08210107e-01,
#          5.38804573e-01, -1.37753025e-01, -1.39961828e-01, -1.37983588e-01,
#          6.10472426e-01, -1.39322912e-01, -1.18600125e-01, -6.19829956e-01,
#          6.99376769e-01, -1.37136880e-01, -8.66105151e-02, -2.21085823e+00,
#          5.74763963e-01, -1.41840863e-01, -1.35483801e-01, -2.02001312e-01,
#          6.33478783e-01, -1.16051182e-01,  3.56153469e-02, -1.67508766e+01]),
#  'split4_test_score': array([ -0.06665348,  -0.12442819,  -0.17932768,  -0.10871636,
#           0.50851762,  -0.20955111,  -0.1892193 ,  -0.13040193,
#           0.58949358,  -0.21314497,  -0.16416545,  -0.53924566,
#           0.67795161,  -0.20640524,  -0.13449284,  -1.94252105,
#           0.55542032,  -0.21644483,  -0.18291868,  -0.18095347,
#           0.69869163,  -0.17930409,  -0.02092444, -15.01216755]),
#  'mean_test_score': array([-6.08619573e-03, -1.01276198e-01, -1.25899020e-01, -1.07639026e-01,
#          5.35224744e-01, -1.47633859e-01, -1.34749222e-01, -1.37843088e-01,
#          6.07678194e-01, -1.49042083e-01, -1.12431736e-01, -6.23810245e-01,
#          6.93778210e-01, -1.44192505e-01, -8.06950833e-02, -2.21544064e+00,
#          5.74408659e-01, -1.51630214e-01, -1.30102114e-01, -1.98977860e-01,
#          6.73913747e-01, -1.20018118e-01,  4.00354972e-02, -1.69838559e+01]),
#  'std_test_score': array([0.03467157, 0.01645872, 0.03179394, 0.01202922, 0.01812189,
#         0.03551124, 0.03394787, 0.01426274, 0.01724249, 0.03700589,
#         0.03272727, 0.07340942, 0.02295499, 0.036262  , 0.03379451,
#         0.25540914, 0.0163307 , 0.037448  , 0.03320478, 0.01880193,
#         0.03987603, 0.03457804, 0.03806422, 1.91478335]),
#  'rank_test_score': array([ 7,  9, 13, 10,  5, 18, 15, 16,  3, 19, 11, 22,  1, 17,  8, 23,  4,
#         20, 14, 21,  2, 12,  6, 24])}

# %%
svr_re = svr_grid.cv_results_

dt_re = dt_grid.cv_results_

rf_re = rf_grid.cv_results_

# table = pd.DataFrame.from_dict(re)
# table

# %%
svr_re
# Out:
# {'mean_fit_time': array([0.34333005, 0.13523641, 0.11353493, 0.14880171, 0.26774311,
#         0.12534394, 0.11748881, 0.14321241, 0.66019373, 0.13025155,
#         0.13505635, 0.14797268, 1.05670171, 0.13535371, 0.16219506,
#         0.14702778, 0.45984187, 0.121523  , 0.13030853, 0.14870968,
#         3.11322646, 0.14280272, 0.2374629 , 0.15183377]),
#  'std_fit_time': array([0.10824036, 0.00560625, 0.00923474, 0.0101538 , 0.01644888,
#         0.00252294, 0.00490638, 0.00320633, 0.06652302, 0.00304119,
#         0.00426335, 0.00595514, 0.11877554, 0.00650162, 0.00740094,
#         0.00357321, 0.17797399, 0.0016132 , 0.00229509, 0.00707257,
#         0.72732969, 0.00522485, 0.01502347, 0.00572224]),
#  'mean_score_time': array([0.0913125 , 0.06956997, 0.01876988, 0.03015513, 0.01849747,
#         0.06748571, 0.01926751, 0.03114781, 0.01675968, 0.06536684,
#         0.01809578, 0.03220272, 0.01646461, 0.06664467, 0.0189497 ,
#         0.03051629, 0.01740751, 0.06600699, 0.01877265, 0.03123512,
#         0.01481776, 0.06326337, 0.01805449, 0.03053575]),
#  'std_score_time': array([0.03653839, 0.00269495, 0.00039726, 0.00170752, 0.00198269,
#         0.00194922, 0.00087651, 0.00178222, 0.00116397, 0.00178656,
#         0.00081403, 0.00186163, 0.00063364, 0.00453427, 0.00089239,
#         0.00148867, 0.00077871, 0.00203305, 0.00114843, 0.001121  ,
#         0.00286065, 0.00136746, 0.00020397, 0.00375422]),
#  'param_C': masked_array(data=[10, 10, 10, 10, 100, 100, 100, 100, 500, 500, 500, 500,
#                     1000, 1000, 1000, 1000, 200, 200, 200, 200, 3000, 3000,
#                     3000, 3000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['linear', 'rbf', 'poly', 'sigmoid', 'linear', 'rbf',
#                     'poly', 'sigmoid', 'linear', 'rbf', 'poly', 'sigmoid',
#                     'linear', 'rbf', 'poly', 'sigmoid', 'linear', 'rbf',
#                     'poly', 'sigmoid', 'linear', 'rbf', 'poly', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'poly'},
#   {'C': 10, 'kernel': 'sigmoid'},
#   {'C': 100, 'kernel': 'linear'},
#   {'C': 100, 'kernel': 'rbf'},
#   {'C': 100, 'kernel': 'poly'},
#   {'C': 100, 'kernel': 'sigmoid'},
#   {'C': 500, 'kernel': 'linear'},
#   {'C': 500, 'kernel': 'rbf'},
#   {'C': 500, 'kernel': 'poly'},
#   {'C': 500, 'kernel': 'sigmoid'},
#   {'C': 1000, 'kernel': 'linear'},
#   {'C': 1000, 'kernel': 'rbf'},
#   {'C': 1000, 'kernel': 'poly'},
#   {'C': 1000, 'kernel': 'sigmoid'},
#   {'C': 200, 'kernel': 'linear'},
#   {'C': 200, 'kernel': 'rbf'},
#   {'C': 200, 'kernel': 'poly'},
#   {'C': 200, 'kernel': 'sigmoid'},
#   {'C': 3000, 'kernel': 'linear'},
#   {'C': 3000, 'kernel': 'rbf'},
#   {'C': 3000, 'kernel': 'poly'},
#   {'C': 3000, 'kernel': 'sigmoid'}],
#  'split0_test_score': array([ -0.0189429 ,  -0.11040913,  -0.12515269,  -0.11674324,
#           0.55931297,  -0.16018172,  -0.13288461,  -0.14245497,
#           0.63213476,  -0.16091649,  -0.11199451,  -0.59087785,
#           0.7363985 ,  -0.15543029,  -0.0805268 ,  -2.04313994,
#           0.59754018,  -0.16437403,  -0.12863679,  -0.19990884,
#           0.67777829,  -0.12895834,   0.03769959, -15.56185339]),
#  'split1_test_score': array([  0.02988647,  -0.09745886,  -0.08150541,  -0.11931157,
#           0.52179776,  -0.10725311,  -0.08246084,  -0.16083065,
#           0.58719506,  -0.10351408,  -0.06145466,  -0.75976455,
#           0.6751618 ,  -0.09826656,  -0.02846903,  -2.68612062,
#           0.55753768,  -0.10642599,  -0.07846791,  -0.23183623,
#           0.62681429,  -0.07557819,   0.0984962 , -20.49890817]),
#  'split2_test_score': array([  0.02216742,  -0.07448755,  -0.11190705,  -0.08521385,
#           0.5476908 ,  -0.12343034,  -0.12921953,  -0.1175443 ,
#           0.61909515,  -0.12831196,  -0.10594393,  -0.60933322,
#           0.68000238,  -0.12372356,  -0.07337624,  -2.19456334,
#           0.58678115,  -0.12906536,  -0.12500339,  -0.18018945,
#           0.73280574,  -0.10019878,   0.0492908 , -17.09547395]),
#  'split3_test_score': array([ 3.11150946e-03, -9.95972567e-02, -1.31602268e-01, -1.08210107e-01,
#          5.38804573e-01, -1.37753025e-01, -1.39961828e-01, -1.37983588e-01,
#          6.10472426e-01, -1.39322912e-01, -1.18600125e-01, -6.19829956e-01,
#          6.99376769e-01, -1.37136880e-01, -8.66105151e-02, -2.21085823e+00,
#          5.74763963e-01, -1.41840863e-01, -1.35483801e-01, -2.02001312e-01,
#          6.33478783e-01, -1.16051182e-01,  3.56153469e-02, -1.67508766e+01]),
#  'split4_test_score': array([ -0.06665348,  -0.12442819,  -0.17932768,  -0.10871636,
#           0.50851762,  -0.20955111,  -0.1892193 ,  -0.13040193,
#           0.58949358,  -0.21314497,  -0.16416545,  -0.53924566,
#           0.67795161,  -0.20640524,  -0.13449284,  -1.94252105,
#           0.55542032,  -0.21644483,  -0.18291868,  -0.18095347,
#           0.69869163,  -0.17930409,  -0.02092444, -15.01216755]),
#  'mean_test_score': array([-6.08619573e-03, -1.01276198e-01, -1.25899020e-01, -1.07639026e-01,
#          5.35224744e-01, -1.47633859e-01, -1.34749222e-01, -1.37843088e-01,
#          6.07678194e-01, -1.49042083e-01, -1.12431736e-01, -6.23810245e-01,
#          6.93778210e-01, -1.44192505e-01, -8.06950833e-02, -2.21544064e+00,
#          5.74408659e-01, -1.51630214e-01, -1.30102114e-01, -1.98977860e-01,
#          6.73913747e-01, -1.20018118e-01,  4.00354972e-02, -1.69838559e+01]),
#  'std_test_score': array([0.03467157, 0.01645872, 0.03179394, 0.01202922, 0.01812189,
#         0.03551124, 0.03394787, 0.01426274, 0.01724249, 0.03700589,
#         0.03272727, 0.07340942, 0.02295499, 0.036262  , 0.03379451,
#         0.25540914, 0.0163307 , 0.037448  , 0.03320478, 0.01880193,
#         0.03987603, 0.03457804, 0.03806422, 1.91478335]),
#  'rank_test_score': array([ 7,  9, 13, 10,  5, 18, 15, 16,  3, 19, 11, 22,  1, 17,  8, 23,  4,
#         20, 14, 21,  2, 12,  6, 24])}

# %%
dt_re
# Out:
# {'mean_fit_time': array([0.19021664, 0.00857568, 0.00916729, 0.00937667, 0.01076188,
#         0.00877419, 0.01038446, 0.01179872, 0.01106653, 0.00767717,
#         0.0111701 , 0.0082912 , 0.04882097, 0.03371563, 0.03014779,
#         0.02194676, 0.02944384, 0.02345672, 0.01936679, 0.01461787,
#         0.01438174, 0.01458225, 0.01416268, 0.01257792]),
#  'std_fit_time': array([0.08470032, 0.00101698, 0.00213408, 0.00205299, 0.00239342,
#         0.00146613, 0.00049624, 0.00574061, 0.00261098, 0.00124504,
#         0.00540795, 0.00243204, 0.00109025, 0.00131405, 0.00281918,
#         0.00206983, 0.00305196, 0.00100584, 0.00544316, 0.00091629,
#         0.00198492, 0.00104062, 0.00116166, 0.00101743]),
#  'mean_score_time': array([0.0061832 , 0.00618491, 0.00638371, 0.00638103, 0.00478764,
#         0.00719504, 0.00518651, 0.00498166, 0.00631251, 0.00561128,
#         0.00518513, 0.00619564, 0.00398984, 0.00359025, 0.00409288,
#         0.00559716, 0.00478759, 0.0046957 , 0.0046936 , 0.00405598,
#         0.0053894 , 0.00458698, 0.00598364, 0.0045722 ]),
#  'std_score_time': array([1.93151988e-03, 1.16403692e-03, 1.62025290e-03, 1.19965043e-03,
#         9.77272147e-04, 2.01879102e-03, 9.66241237e-04, 8.94173408e-04,
#         2.39183063e-03, 1.89738443e-03, 9.78163958e-04, 2.91335264e-03,
#         9.60800251e-07, 4.89026452e-04, 7.95246097e-04, 1.35684028e-03,
#         1.16200186e-03, 9.75526825e-04, 1.52641888e-03, 4.97727847e-04,
#         1.35090819e-03, 7.97122409e-04, 1.89393826e-03, 1.14361531e-03]),
#  'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'squared_error', 'squared_error',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                     'poisson'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[None, None, 'sqrt', 'sqrt', 'log2', 'log2', None, None,
#                     'sqrt', 'sqrt', 'log2', 'log2', None, None, 'sqrt',
#                     'sqrt', 'log2', 'log2', None, None, 'sqrt', 'sqrt',
#                     'log2', 'log2'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_splitter': masked_array(data=['best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'random'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'squared_error',
#    'max_features': None,
#    'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': None, 'splitter': 'random'},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': None, 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': None, 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'best'},
#   {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'absolute_error',
#    'max_features': 'sqrt',
#    'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'absolute_error',
#    'max_features': 'log2',
#    'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': None, 'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'random'}],
#  'split0_test_score': array([0.72783581, 0.68561255, 0.75288765, 0.69516413, 0.75449479,
#         0.61276172, 0.72400322, 0.73827437, 0.66549387, 0.72844403,
#         0.72787071, 0.57648517, 0.73807421, 0.67848643, 0.70155407,
#         0.72022758, 0.71904006, 0.76101243, 0.74784905, 0.73234869,
#         0.76274081, 0.61052392, 0.66108118, 0.67547675]),
#  'split1_test_score': array([0.61365601, 0.6205916 , 0.62733614, 0.5344637 , 0.63652255,
#         0.53152021, 0.65654538, 0.58775706, 0.57408478, 0.49273528,
#         0.58436384, 0.49631477, 0.62193152, 0.65058272, 0.69997953,
#         0.62621354, 0.3648436 , 0.43943781, 0.6650195 , 0.6553774 ,
#         0.55731526, 0.57425914, 0.65628595, 0.59626912]),
#  'split2_test_score': array([0.73202759, 0.73826953, 0.71303212, 0.71988507, 0.72116202,
#         0.74382391, 0.72927541, 0.74192651, 0.70370542, 0.63068088,
#         0.71565518, 0.71640067, 0.69348761, 0.74543197, 0.69420457,
#         0.69456333, 0.72163375, 0.72355612, 0.75982499, 0.75838918,
#         0.73697598, 0.66732075, 0.69963607, 0.76326197]),
#  'split3_test_score': array([0.73465542, 0.67943303, 0.704302  , 0.72020774, 0.63997531,
#         0.66195656, 0.71423231, 0.76096986, 0.70391064, 0.61286061,
#         0.7286906 , 0.58248187, 0.74258997, 0.68758348, 0.70973699,
#         0.57641852, 0.61904439, 0.70972872, 0.71978175, 0.65657655,
#         0.58832269, 0.71228039, 0.67892795, 0.61843169]),
#  'split4_test_score': array([0.68104682, 0.69637359, 0.65316798, 0.65999019, 0.70020247,
#         0.66798629, 0.68569804, 0.6983107 , 0.71992053, 0.68592913,
#         0.57344406, 0.59497481, 0.73910694, 0.73188438, 0.73491247,
#         0.6878688 , 0.71817459, 0.65219916, 0.69533692, 0.71559671,
#         0.7033314 , 0.68007361, 0.74203419, 0.66371862]),
#  'mean_test_score': array([0.69784433, 0.68405606, 0.69014518, 0.66594217, 0.69047143,
#         0.64360974, 0.70195088, 0.7054477 , 0.67342305, 0.63012998,
#         0.66600488, 0.59333146, 0.70703805, 0.6987938 , 0.70807753,
#         0.66105835, 0.62854728, 0.65718685, 0.71756244, 0.70365771,
#         0.66973723, 0.64889156, 0.68759307, 0.66343163]),
#  'std_test_score': array([0.04646046, 0.03779512, 0.04466124, 0.06932608, 0.04603463,
#         0.06998481, 0.02723815, 0.06227845, 0.05280056, 0.07994377,
#         0.07135096, 0.0706576 , 0.04622193, 0.03502135, 0.01430706,
#         0.05238405, 0.13748965, 0.11435454, 0.03453422, 0.04125256,
#         0.0819345 , 0.04974369, 0.03119926, 0.05770106]),
#  'rank_test_score': array([ 8, 12, 10, 16,  9, 21,  6,  4, 13, 22, 15, 24,  3,  7,  2, 18, 23,
#         19,  1,  5, 14, 20, 11, 17])}

# %%
rf_re
# Out:
# {'mean_fit_time': array([0.60988779, 0.63639655, 0.09140177, 0.4511939 , 0.05427341,
#         0.45705824, 0.06725082, 0.58190513, 0.05377026, 0.45709243,
#         0.05587664, 0.45736814, 0.25096202, 2.43444552, 0.1448523 ,
#         1.55822968, 0.17405405, 1.64774876, 0.12434487, 0.94980602,
#         0.08976398, 0.79896364, 0.09640284, 0.75980954]),
#  'std_fit_time': array([0.27084272, 0.07154381, 0.03150187, 0.01472615, 0.00150839,
#         0.00742414, 0.00410764, 0.00464011, 0.00146095, 0.01607287,
#         0.00280146, 0.01560074, 0.00441575, 0.06019631, 0.00560625,
#         0.12543831, 0.02502388, 0.02941994, 0.02062356, 0.0214392 ,
#         0.00472656, 0.01945552, 0.01531528, 0.11608556]),
#  'mean_score_time': array([0.00619087, 0.05366449, 0.00698214, 0.02218542, 0.00699492,
#         0.02027955, 0.00610242, 0.02054968, 0.00717645, 0.02517276,
#         0.00759392, 0.0197793 , 0.00691943, 0.01806097, 0.00669618,
#         0.01926575, 0.00600038, 0.02193127, 0.00718126, 0.01946158,
#         0.01067023, 0.02445364, 0.005792  , 0.01979766]),
#  'std_score_time': array([0.00098866, 0.03036999, 0.00089244, 0.00201549, 0.00109849,
#         0.00170791, 0.00066966, 0.00224947, 0.00115454, 0.00429338,
#         0.00185238, 0.00347508, 0.00163783, 0.00048479, 0.00073542,
#         0.00107169, 0.00109292, 0.00335585, 0.0011631 , 0.00172212,
#         0.0086352 , 0.00793112, 0.00074836, 0.00449201]),
#  'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'squared_error', 'squared_error',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                     'poisson'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[None, None, 'sqrt', 'sqrt', 'log2', 'log2', None, None,
#                     'sqrt', 'sqrt', 'log2', 'log2', None, None, 'sqrt',
#                     'sqrt', 'log2', 'log2', None, None, 'sqrt', 'sqrt',
#                     'log2', 'log2'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[10, 100, 10, 100, 10, 100, 10, 100, 10, 100, 10, 100,
#                     10, 100, 10, 100, 10, 100, 10, 100, 10, 100, 10, 100],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'params': [{'criterion': 'squared_error',
#    'max_features': None,
#    'n_estimators': 10},
#   {'criterion': 'squared_error', 'max_features': None, 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'friedman_mse', 'max_features': None, 'n_estimators': 10},
#   {'criterion': 'friedman_mse', 'max_features': None, 'n_estimators': 100},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_features': None, 'n_estimators': 10},
#   {'criterion': 'absolute_error', 'max_features': None, 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': None, 'n_estimators': 10},
#   {'criterion': 'poisson', 'max_features': None, 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}],
#  'split0_test_score': array([0.83214259, 0.84916553, 0.8484012 , 0.85438436, 0.83135443,
#         0.8574085 , 0.83521087, 0.84799165, 0.84193373, 0.85765439,
#         0.84694449, 0.85616514, 0.82218648, 0.83892154, 0.81904833,
#         0.85661489, 0.85213519, 0.85585392, 0.8449407 , 0.84853099,
#         0.83243635, 0.85819608, 0.83554682, 0.85452943]),
#  'split1_test_score': array([0.75451586, 0.77002969, 0.74793348, 0.77862234, 0.7358429 ,
#         0.78003118, 0.76583334, 0.77340339, 0.76383764, 0.7831621 ,
#         0.75654119, 0.77686179, 0.76839246, 0.76808542, 0.74097258,
#         0.78156973, 0.7598089 , 0.77990318, 0.75921778, 0.76329112,
#         0.76737979, 0.78341379, 0.76857962, 0.77712225]),
#  'split2_test_score': array([0.8417483 , 0.85629647, 0.85174553, 0.85450741, 0.85144718,
#         0.86629194, 0.83903692, 0.85111021, 0.85665776, 0.86432325,
#         0.84685203, 0.86360272, 0.83928768, 0.84771656, 0.83133543,
#         0.85218431, 0.83113544, 0.85984041, 0.82905477, 0.85807531,
#         0.84729293, 0.86073302, 0.83495251, 0.85918018]),
#  'split3_test_score': array([0.80205575, 0.81585792, 0.82966233, 0.8257755 , 0.81565458,
#         0.83094577, 0.80293138, 0.81548948, 0.8083838 , 0.82859118,
#         0.81171614, 0.82791756, 0.82761845, 0.82396979, 0.80421383,
#         0.83245374, 0.79966354, 0.82594146, 0.81229325, 0.81943104,
#         0.80943125, 0.82990093, 0.81830909, 0.82651161]),
#  'split4_test_score': array([0.80897463, 0.83455284, 0.82692277, 0.83634777, 0.8248984 ,
#         0.83842724, 0.83528829, 0.83589721, 0.82607661, 0.83853249,
#         0.83580722, 0.84246019, 0.82572019, 0.83783807, 0.81295913,
#         0.84356462, 0.82036273, 0.84317523, 0.83414583, 0.83708887,
#         0.83169388, 0.83886683, 0.83759479, 0.84858974]),
#  'mean_test_score': array([0.80788742, 0.82518049, 0.82093306, 0.82992747, 0.8118395 ,
#         0.83462093, 0.81566016, 0.82477839, 0.81937791, 0.83445268,
#         0.81957221, 0.83340148, 0.81664105, 0.82330628, 0.80170586,
#         0.83327746, 0.81262116, 0.83294284, 0.81593047, 0.82528347,
#         0.81764684, 0.83422213, 0.81899657, 0.83318664]),
#  'std_test_score': array([0.03039272, 0.03085401, 0.03780191, 0.02790336, 0.0397748 ,
#         0.03010104, 0.02813788, 0.02857104, 0.03209055, 0.02867855,
#         0.0340342 , 0.03078691, 0.0247971 , 0.02863793, 0.03162319,
#         0.02713779, 0.03137229, 0.02903558, 0.03024962, 0.03356314,
#         0.02788982, 0.02792601, 0.02614092, 0.03018677]),
#  'rank_test_score': array([23, 10, 13,  8, 22,  1, 20, 11, 15,  2, 14,  4, 18, 12, 24,  5, 21,
#          7, 19,  9, 17,  3, 16,  6])}

# %%
svr_table = pd.DataFrame.from_dict(svr_re)
svr_table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.343330      0.108240         0.091313        0.036538       10
# 1        0.135236      0.005606         0.069570        0.002695       10
# 2        0.113535      0.009235         0.018770        0.000397       10
# 3        0.148802      0.010154         0.030155        0.001708       10
# 4        0.267743      0.016449         0.018497        0.001983      100
# 5        0.125344      0.002523         0.067486        0.001949      100
# 6        0.117489      0.004906         0.019268        0.000877      100
# 7        0.143212      0.003206         0.031148        0.001782      100
# 8        0.660194      0.066523         0.016760        0.001164      500
# 9        0.130252      0.003041         0.065367        0.001787      500
# 10       0.135056      0.004263         0.018096        0.000814      500
# 11       0.147973      0.005955         0.032203        0.001862      500
# 12       1.056702      0.118776         0.016465        0.000634     1000
# 13       0.135354      0.006502         0.066645        0.004534     1000
# 14       0.162195      0.007401         0.018950        0.000892     1000
# 15       0.147028      0.003573         0.030516        0.001489     1000
# 16       0.459842      0.177974         0.017408        0.000779      200
# 17       0.121523      0.001613         0.066007        0.002033      200
# 18       0.130309      0.002295         0.018773        0.001148      200
# 19       0.148710      0.007073         0.031235        0.001121      200
# 20       3.113226      0.727330         0.014818        0.002861     3000
# 21       0.142803      0.005225         0.063263        0.001367     3000
# 22       0.237463      0.015023         0.018054        0.000204     3000
# 23       0.151834      0.005722         0.030536        0.003754     3000
#
#    param_kernel                            params  split0_test_score  \
# 0        linear     {'C': 10, 'kernel': 'linear'}          -0.018943
# 1           rbf        {'C': 10, 'kernel': 'rbf'}          -0.110409
# 2          poly       {'C': 10, 'kernel': 'poly'}          -0.125153
# 3       sigmoid    {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 4        linear    {'C': 100, 'kernel': 'linear'}           0.559313
# 5           rbf       {'C': 100, 'kernel': 'rbf'}          -0.160182
# 6          poly      {'C': 100, 'kernel': 'poly'}          -0.132885
# 7       sigmoid   {'C': 100, 'kernel': 'sigmoid'}          -0.142455
# 8        linear    {'C': 500, 'kernel': 'linear'}           0.632135
# 9           rbf       {'C': 500, 'kernel': 'rbf'}          -0.160916
# 10         poly      {'C': 500, 'kernel': 'poly'}          -0.111995
# 11      sigmoid   {'C': 500, 'kernel': 'sigmoid'}          -0.590878
# 12       linear   {'C': 1000, 'kernel': 'linear'}           0.736398
# 13          rbf      {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 14         poly     {'C': 1000, 'kernel': 'poly'}          -0.080527
# 15      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}          -2.043140
# 16       linear    {'C': 200, 'kernel': 'linear'}           0.597540
# 17          rbf       {'C': 200, 'kernel': 'rbf'}          -0.164374
# 18         poly      {'C': 200, 'kernel': 'poly'}          -0.128637
# 19      sigmoid   {'C': 200, 'kernel': 'sigmoid'}          -0.199909
# 20       linear   {'C': 3000, 'kernel': 'linear'}           0.677778
# 21          rbf      {'C': 3000, 'kernel': 'rbf'}          -0.128958
# 22         poly     {'C': 3000, 'kernel': 'poly'}           0.037700
# 23      sigmoid  {'C': 3000, 'kernel': 'sigmoid'}         -15.561853
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.029886           0.022167           0.003112
# 1           -0.097459          -0.074488          -0.099597
# 2           -0.081505          -0.111907          -0.131602
# 3           -0.119312          -0.085214          -0.108210
# 4            0.521798           0.547691           0.538805
# 5           -0.107253          -0.123430          -0.137753
# 6           -0.082461          -0.129220          -0.139962
# 7           -0.160831          -0.117544          -0.137984
# 8            0.587195           0.619095           0.610472
# 9           -0.103514          -0.128312          -0.139323
# 10          -0.061455          -0.105944          -0.118600
# 11          -0.759765          -0.609333          -0.619830
# 12           0.675162           0.680002           0.699377
# 13          -0.098267          -0.123724          -0.137137
# 14          -0.028469          -0.073376          -0.086611
# 15          -2.686121          -2.194563          -2.210858
# 16           0.557538           0.586781           0.574764
# 17          -0.106426          -0.129065          -0.141841
# 18          -0.078468          -0.125003          -0.135484
# 19          -0.231836          -0.180189          -0.202001
# 20           0.626814           0.732806           0.633479
# 21          -0.075578          -0.100199          -0.116051
# 22           0.098496           0.049291           0.035615
# 23         -20.498908         -17.095474         -16.750877
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.066653        -0.006086        0.034672                7
# 1           -0.124428        -0.101276        0.016459                9
# 2           -0.179328        -0.125899        0.031794               13
# 3           -0.108716        -0.107639        0.012029               10
# 4            0.508518         0.535225        0.018122                5
# 5           -0.209551        -0.147634        0.035511               18
# 6           -0.189219        -0.134749        0.033948               15
# 7           -0.130402        -0.137843        0.014263               16
# 8            0.589494         0.607678        0.017242                3
# 9           -0.213145        -0.149042        0.037006               19
# 10          -0.164165        -0.112432        0.032727               11
# 11          -0.539246        -0.623810        0.073409               22
# 12           0.677952         0.693778        0.022955                1
# 13          -0.206405        -0.144193        0.036262               17
# 14          -0.134493        -0.080695        0.033795                8
# 15          -1.942521        -2.215441        0.255409               23
# 16           0.555420         0.574409        0.016331                4
# 17          -0.216445        -0.151630        0.037448               20
# 18          -0.182919        -0.130102        0.033205               14
# 19          -0.180953        -0.198978        0.018802               21
# 20           0.698692         0.673914        0.039876                2
# 21          -0.179304        -0.120018        0.034578               12
# 22          -0.020924         0.040035        0.038064                6
# 23         -15.012168       -16.983856        1.914783               24

# %%
dt_table = pd.DataFrame.from_dict(dt_re)
dt_table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.190217      0.084700         0.006183    1.931520e-03
# 1        0.008576      0.001017         0.006185    1.164037e-03
# 2        0.009167      0.002134         0.006384    1.620253e-03
# 3        0.009377      0.002053         0.006381    1.199650e-03
# 4        0.010762      0.002393         0.004788    9.772721e-04
# 5        0.008774      0.001466         0.007195    2.018791e-03
# 6        0.010384      0.000496         0.005187    9.662412e-04
# 7        0.011799      0.005741         0.004982    8.941734e-04
# 8        0.011067      0.002611         0.006313    2.391831e-03
# 9        0.007677      0.001245         0.005611    1.897384e-03
# 10       0.011170      0.005408         0.005185    9.781640e-04
# 11       0.008291      0.002432         0.006196    2.913353e-03
# 12       0.048821      0.001090         0.003990    9.608003e-07
# 13       0.033716      0.001314         0.003590    4.890265e-04
# 14       0.030148      0.002819         0.004093    7.952461e-04
# 15       0.021947      0.002070         0.005597    1.356840e-03
# 16       0.029444      0.003052         0.004788    1.162002e-03
# 17       0.023457      0.001006         0.004696    9.755268e-04
# 18       0.019367      0.005443         0.004694    1.526419e-03
# 19       0.014618      0.000916         0.004056    4.977278e-04
# 20       0.014382      0.001985         0.005389    1.350908e-03
# 21       0.014582      0.001041         0.004587    7.971224e-04
# 22       0.014163      0.001162         0.005984    1.893938e-03
# 23       0.012578      0.001017         0.004572    1.143615e-03
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               None           best
# 7     friedman_mse               None         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               None           best
# 13  absolute_error               None         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.727836
# 1   {'criterion': 'squared_error', 'max_features':...           0.685613
# 2   {'criterion': 'squared_error', 'max_features':...           0.752888
# 3   {'criterion': 'squared_error', 'max_features':...           0.695164
# 4   {'criterion': 'squared_error', 'max_features':...           0.754495
# 5   {'criterion': 'squared_error', 'max_features':...           0.612762
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.724003
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.738274
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.665494
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.728444
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.727871
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.576485
# 12  {'criterion': 'absolute_error', 'max_features'...           0.738074
# 13  {'criterion': 'absolute_error', 'max_features'...           0.678486
# 14  {'criterion': 'absolute_error', 'max_features'...           0.701554
# 15  {'criterion': 'absolute_error', 'max_features'...           0.720228
# 16  {'criterion': 'absolute_error', 'max_features'...           0.719040
# 17  {'criterion': 'absolute_error', 'max_features'...           0.761012
# 18  {'criterion': 'poisson', 'max_features': None,...           0.747849
# 19  {'criterion': 'poisson', 'max_features': None,...           0.732349
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.762741
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.610524
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.661081
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.675477
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.613656           0.732028           0.734655
# 1            0.620592           0.738270           0.679433
# 2            0.627336           0.713032           0.704302
# 3            0.534464           0.719885           0.720208
# 4            0.636523           0.721162           0.639975
# 5            0.531520           0.743824           0.661957
# 6            0.656545           0.729275           0.714232
# 7            0.587757           0.741927           0.760970
# 8            0.574085           0.703705           0.703911
# 9            0.492735           0.630681           0.612861
# 10           0.584364           0.715655           0.728691
# 11           0.496315           0.716401           0.582482
# 12           0.621932           0.693488           0.742590
# 13           0.650583           0.745432           0.687583
# 14           0.699980           0.694205           0.709737
# 15           0.626214           0.694563           0.576419
# 16           0.364844           0.721634           0.619044
# 17           0.439438           0.723556           0.709729
# 18           0.665020           0.759825           0.719782
# 19           0.655377           0.758389           0.656577
# 20           0.557315           0.736976           0.588323
# 21           0.574259           0.667321           0.712280
# 22           0.656286           0.699636           0.678928
# 23           0.596269           0.763262           0.618432
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.681047         0.697844        0.046460                8
# 1            0.696374         0.684056        0.037795               12
# 2            0.653168         0.690145        0.044661               10
# 3            0.659990         0.665942        0.069326               16
# 4            0.700202         0.690471        0.046035                9
# 5            0.667986         0.643610        0.069985               21
# 6            0.685698         0.701951        0.027238                6
# 7            0.698311         0.705448        0.062278                4
# 8            0.719921         0.673423        0.052801               13
# 9            0.685929         0.630130        0.079944               22
# 10           0.573444         0.666005        0.071351               15
# 11           0.594975         0.593331        0.070658               24
# 12           0.739107         0.707038        0.046222                3
# 13           0.731884         0.698794        0.035021                7
# 14           0.734912         0.708078        0.014307                2
# 15           0.687869         0.661058        0.052384               18
# 16           0.718175         0.628547        0.137490               23
# 17           0.652199         0.657187        0.114355               19
# 18           0.695337         0.717562        0.034534                1
# 19           0.715597         0.703658        0.041253                5
# 20           0.703331         0.669737        0.081934               14
# 21           0.680074         0.648892        0.049744               20
# 22           0.742034         0.687593        0.031199               11
# 23           0.663719         0.663432        0.057701               17

# %%
rf_table = pd.DataFrame.from_dict(rf_re)
rf_table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.609888      0.270843         0.006191        0.000989
# 1        0.636397      0.071544         0.053664        0.030370
# 2        0.091402      0.031502         0.006982        0.000892
# 3        0.451194      0.014726         0.022185        0.002015
# 4        0.054273      0.001508         0.006995        0.001098
# 5        0.457058      0.007424         0.020280        0.001708
# 6        0.067251      0.004108         0.006102        0.000670
# 7        0.581905      0.004640         0.020550        0.002249
# 8        0.053770      0.001461         0.007176        0.001155
# 9        0.457092      0.016073         0.025173        0.004293
# 10       0.055877      0.002801         0.007594        0.001852
# 11       0.457368      0.015601         0.019779        0.003475
# 12       0.250962      0.004416         0.006919        0.001638
# 13       2.434446      0.060196         0.018061        0.000485
# 14       0.144852      0.005606         0.006696        0.000735
# 15       1.558230      0.125438         0.019266        0.001072
# 16       0.174054      0.025024         0.006000        0.001093
# 17       1.647749      0.029420         0.021931        0.003356
# 18       0.124345      0.020624         0.007181        0.001163
# 19       0.949806      0.021439         0.019462        0.001722
# 20       0.089764      0.004727         0.010670        0.008635
# 21       0.798964      0.019456         0.024454        0.007931
# 22       0.096403      0.015315         0.005792        0.000748
# 23       0.759810      0.116086         0.019798        0.004492
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  10
# 1    squared_error               None                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6     friedman_mse               None                  10
# 7     friedman_mse               None                 100
# 8     friedman_mse               sqrt                  10
# 9     friedman_mse               sqrt                 100
# 10    friedman_mse               log2                  10
# 11    friedman_mse               log2                 100
# 12  absolute_error               None                  10
# 13  absolute_error               None                 100
# 14  absolute_error               sqrt                  10
# 15  absolute_error               sqrt                 100
# 16  absolute_error               log2                  10
# 17  absolute_error               log2                 100
# 18         poisson               None                  10
# 19         poisson               None                 100
# 20         poisson               sqrt                  10
# 21         poisson               sqrt                 100
# 22         poisson               log2                  10
# 23         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.832143
# 1   {'criterion': 'squared_error', 'max_features':...           0.849166
# 2   {'criterion': 'squared_error', 'max_features':...           0.848401
# 3   {'criterion': 'squared_error', 'max_features':...           0.854384
# 4   {'criterion': 'squared_error', 'max_features':...           0.831354
# 5   {'criterion': 'squared_error', 'max_features':...           0.857409
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.835211
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.847992
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.841934
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.857654
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.846944
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.856165
# 12  {'criterion': 'absolute_error', 'max_features'...           0.822186
# 13  {'criterion': 'absolute_error', 'max_features'...           0.838922
# 14  {'criterion': 'absolute_error', 'max_features'...           0.819048
# 15  {'criterion': 'absolute_error', 'max_features'...           0.856615
# 16  {'criterion': 'absolute_error', 'max_features'...           0.852135
# 17  {'criterion': 'absolute_error', 'max_features'...           0.855854
# 18  {'criterion': 'poisson', 'max_features': None,...           0.844941
# 19  {'criterion': 'poisson', 'max_features': None,...           0.848531
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.832436
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.858196
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.835547
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.854529
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.754516           0.841748           0.802056
# 1            0.770030           0.856296           0.815858
# 2            0.747933           0.851746           0.829662
# 3            0.778622           0.854507           0.825775
# 4            0.735843           0.851447           0.815655
# 5            0.780031           0.866292           0.830946
# 6            0.765833           0.839037           0.802931
# 7            0.773403           0.851110           0.815489
# 8            0.763838           0.856658           0.808384
# 9            0.783162           0.864323           0.828591
# 10           0.756541           0.846852           0.811716
# 11           0.776862           0.863603           0.827918
# 12           0.768392           0.839288           0.827618
# 13           0.768085           0.847717           0.823970
# 14           0.740973           0.831335           0.804214
# 15           0.781570           0.852184           0.832454
# 16           0.759809           0.831135           0.799664
# 17           0.779903           0.859840           0.825941
# 18           0.759218           0.829055           0.812293
# 19           0.763291           0.858075           0.819431
# 20           0.767380           0.847293           0.809431
# 21           0.783414           0.860733           0.829901
# 22           0.768580           0.834953           0.818309
# 23           0.777122           0.859180           0.826512
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.808975         0.807887        0.030393               23
# 1            0.834553         0.825180        0.030854               10
# 2            0.826923         0.820933        0.037802               13
# 3            0.836348         0.829927        0.027903                8
# 4            0.824898         0.811839        0.039775               22
# 5            0.838427         0.834621        0.030101                1
# 6            0.835288         0.815660        0.028138               20
# 7            0.835897         0.824778        0.028571               11
# 8            0.826077         0.819378        0.032091               15
# 9            0.838532         0.834453        0.028679                2
# 10           0.835807         0.819572        0.034034               14
# 11           0.842460         0.833401        0.030787                4
# 12           0.825720         0.816641        0.024797               18
# 13           0.837838         0.823306        0.028638               12
# 14           0.812959         0.801706        0.031623               24
# 15           0.843565         0.833277        0.027138                5
# 16           0.820363         0.812621        0.031372               21
# 17           0.843175         0.832943        0.029036                7
# 18           0.834146         0.815930        0.030250               19
# 19           0.837089         0.825283        0.033563                9
# 20           0.831694         0.817647        0.027890               17
# 21           0.838867         0.834222        0.027926                3
# 22           0.837595         0.818997        0.026141               16
# 23           0.848590         0.833187        0.030187                6

# %%
from sklearn.metrics import r2_score

#SvM R2 Score Value
y_svm_pred = svr_grid.predict(independent)
svm_r2_score = r2_score(dependent,y_svm_pred)
svm_r2_score
# Out:
# 0.7179049746029801

# %%
#Decision Tree R2 Score Value
y_dt_pred = dt_grid.predict(independent)
dt_r2_score = r2_score(dependent,y_dt_pred)
dt_r2_score
# Out:
# 0.998667156135576

# %%
#Random Forest R2 Score Value
y_rf_pred = rf_grid.predict(independent)
rf_r2_score = r2_score(dependent,y_dt_pred)
rf_r2_score
# Out:
# 0.998667156135576

# %%
#Saving the ML Model (Decision Tree Model => R2 Score : 0.99
import pickle 
pickle.dump(dt_grid,open("GRID_SEARCH_FINAL_MODEL.sav","wb"))

# %%
#Predicting Using Decision Tree
dt_res = dt_grid.predict([[24,25.5,0,1,0]])
dt_res
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([2775.19215])
