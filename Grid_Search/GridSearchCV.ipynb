# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,dtype = int, drop_first = True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[["age","sex_male","bmi","children","smoker_yes"]]
dependent = dataset[["charges"]]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
svr_param_grid = {
    "kernel" : ["linear","rbf","poly","sigmoid"],
    "C" : [10,100,500,1000,200,3000] 
}

dt_param_grid = {
    "criterion" : ["squared_error", "friedman_mse", "absolute_error", "poisson"],
    "max_features" : [None, "sqrt","log2"] ,
    "splitter" : ["best","random"]
}

rf_param_grid = {
    "criterion" : ["squared_error", "friedman_mse", "absolute_error", "poisson"],
    "max_features" : [None, "sqrt","log2"] ,
    "n_estimators" : [10,100]
}
 
svr_grid = GridSearchCV(SVR(),svr_param_grid,refit = True,verbose = 3, n_jobs = -1)
dt_grid = GridSearchCV(DecisionTreeRegressor(),dt_param_grid,refit = True,verbose = 3, n_jobs = -1)
rf_grid = GridSearchCV(RandomForestRegressor(),rf_param_grid,refit = True,verbose = 3, n_jobs = -1)

# %%
svr_grid.fit(independent,dependent)
dt_grid.fit(independent,dependent)
rf_grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
svr_grid.best_params_
# Out:
# {'C': 1000, 'kernel': 'linear'}

# %%
dt_grid.best_params_
# Out:
# {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}

# %%
rf_grid.best_params_
# Out:
# {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
svr_grid.cv_results_
# Out:
# {'mean_fit_time': array([0.17552934, 0.13603578, 0.11289763, 0.16435976, 0.29401307,
#         0.14122143, 0.12207351, 0.15139484, 0.65225506, 0.13803148,
#         0.14102249, 0.14899902, 1.03383489, 0.14321585, 0.17273836,
#         0.16115975, 0.53676505, 0.17154217, 0.15837626, 0.17213945,
#         3.16913705, 0.17732601, 0.29660602, 0.16376376]),
#  'std_fit_time': array([0.0270719 , 0.01209295, 0.00336003, 0.00798849, 0.01039148,
#         0.00737172, 0.00371067, 0.00603048, 0.07869215, 0.00569778,
#         0.00723538, 0.00162049, 0.10983066, 0.00663003, 0.00973749,
#         0.01101185, 0.23593144, 0.02520707, 0.01222007, 0.00678233,
#         0.52797327, 0.01801247, 0.0552434 , 0.00820581]),
#  'mean_score_time': array([0.02134447, 0.07021232, 0.01974735, 0.03550763, 0.01914959,
#         0.070612  , 0.01934829, 0.03291225, 0.01795502, 0.06782312,
#         0.01895046, 0.0341095 , 0.01855111, 0.06941419, 0.0195477 ,
#         0.03271461, 0.02413535, 0.08178163, 0.02094393, 0.03789983,
#         0.01635504, 0.07719407, 0.0221416 , 0.03689971]),
#  'std_score_time': array([0.0060685 , 0.00205373, 0.00193392, 0.00376356, 0.0014661 ,
#         0.00247547, 0.00149308, 0.00063037, 0.00209574, 0.0043195 ,
#         0.00109141, 0.00425037, 0.00257027, 0.00354522, 0.00135444,
#         0.00212927, 0.00765791, 0.00862516, 0.00227418, 0.00467944,
#         0.00337698, 0.00396923, 0.00533022, 0.00388824]),
#  'param_C': masked_array(data=[10, 10, 10, 10, 100, 100, 100, 100, 500, 500, 500, 500,
#                     1000, 1000, 1000, 1000, 200, 200, 200, 200, 3000, 3000,
#                     3000, 3000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['linear', 'rbf', 'poly', 'sigmoid', 'linear', 'rbf',
#                     'poly', 'sigmoid', 'linear', 'rbf', 'poly', 'sigmoid',
#                     'linear', 'rbf', 'poly', 'sigmoid', 'linear', 'rbf',
#                     'poly', 'sigmoid', 'linear', 'rbf', 'poly', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'poly'},
#   {'C': 10, 'kernel': 'sigmoid'},
#   {'C': 100, 'kernel': 'linear'},
#   {'C': 100, 'kernel': 'rbf'},
#   {'C': 100, 'kernel': 'poly'},
#   {'C': 100, 'kernel': 'sigmoid'},
#   {'C': 500, 'kernel': 'linear'},
#   {'C': 500, 'kernel': 'rbf'},
#   {'C': 500, 'kernel': 'poly'},
#   {'C': 500, 'kernel': 'sigmoid'},
#   {'C': 1000, 'kernel': 'linear'},
#   {'C': 1000, 'kernel': 'rbf'},
#   {'C': 1000, 'kernel': 'poly'},
#   {'C': 1000, 'kernel': 'sigmoid'},
#   {'C': 200, 'kernel': 'linear'},
#   {'C': 200, 'kernel': 'rbf'},
#   {'C': 200, 'kernel': 'poly'},
#   {'C': 200, 'kernel': 'sigmoid'},
#   {'C': 3000, 'kernel': 'linear'},
#   {'C': 3000, 'kernel': 'rbf'},
#   {'C': 3000, 'kernel': 'poly'},
#   {'C': 3000, 'kernel': 'sigmoid'}],
#  'split0_test_score': array([ -0.0189429 ,  -0.11040913,  -0.12515269,  -0.11674324,
#           0.55931297,  -0.16018172,  -0.13288461,  -0.14245497,
#           0.63213476,  -0.16091649,  -0.11199451,  -0.59087785,
#           0.7363985 ,  -0.15543029,  -0.0805268 ,  -2.04313994,
#           0.59754018,  -0.16437403,  -0.12863679,  -0.19990884,
#           0.67777829,  -0.12895834,   0.03769959, -15.56185339]),
#  'split1_test_score': array([  0.02988647,  -0.09745886,  -0.08150541,  -0.11931157,
#           0.52179776,  -0.10725311,  -0.08246084,  -0.16083065,
#           0.58719506,  -0.10351408,  -0.06145466,  -0.75976455,
#           0.6751618 ,  -0.09826656,  -0.02846903,  -2.68612062,
#           0.55753768,  -0.10642599,  -0.07846791,  -0.23183623,
#           0.62681429,  -0.07557819,   0.0984962 , -20.49890817]),
#  'split2_test_score': array([  0.02216742,  -0.07448755,  -0.11190705,  -0.08521385,
#           0.5476908 ,  -0.12343034,  -0.12921953,  -0.1175443 ,
#           0.61909515,  -0.12831196,  -0.10594393,  -0.60933322,
#           0.68000238,  -0.12372356,  -0.07337624,  -2.19456334,
#           0.58678115,  -0.12906536,  -0.12500339,  -0.18018945,
#           0.73280574,  -0.10019878,   0.0492908 , -17.09547395]),
#  'split3_test_score': array([ 3.11150946e-03, -9.95972567e-02, -1.31602268e-01, -1.08210107e-01,
#          5.38804573e-01, -1.37753025e-01, -1.39961828e-01, -1.37983588e-01,
#          6.10472426e-01, -1.39322912e-01, -1.18600125e-01, -6.19829956e-01,
#          6.99376769e-01, -1.37136880e-01, -8.66105151e-02, -2.21085823e+00,
#          5.74763963e-01, -1.41840863e-01, -1.35483801e-01, -2.02001312e-01,
#          6.33478783e-01, -1.16051182e-01,  3.56153469e-02, -1.67508766e+01]),
#  'split4_test_score': array([ -0.06665348,  -0.12442819,  -0.17932768,  -0.10871636,
#           0.50851762,  -0.20955111,  -0.1892193 ,  -0.13040193,
#           0.58949358,  -0.21314497,  -0.16416545,  -0.53924566,
#           0.67795161,  -0.20640524,  -0.13449284,  -1.94252105,
#           0.55542032,  -0.21644483,  -0.18291868,  -0.18095347,
#           0.69869163,  -0.17930409,  -0.02092444, -15.01216755]),
#  'mean_test_score': array([-6.08619573e-03, -1.01276198e-01, -1.25899020e-01, -1.07639026e-01,
#          5.35224744e-01, -1.47633859e-01, -1.34749222e-01, -1.37843088e-01,
#          6.07678194e-01, -1.49042083e-01, -1.12431736e-01, -6.23810245e-01,
#          6.93778210e-01, -1.44192505e-01, -8.06950833e-02, -2.21544064e+00,
#          5.74408659e-01, -1.51630214e-01, -1.30102114e-01, -1.98977860e-01,
#          6.73913747e-01, -1.20018118e-01,  4.00354972e-02, -1.69838559e+01]),
#  'std_test_score': array([0.03467157, 0.01645872, 0.03179394, 0.01202922, 0.01812189,
#         0.03551124, 0.03394787, 0.01426274, 0.01724249, 0.03700589,
#         0.03272727, 0.07340942, 0.02295499, 0.036262  , 0.03379451,
#         0.25540914, 0.0163307 , 0.037448  , 0.03320478, 0.01880193,
#         0.03987603, 0.03457804, 0.03806422, 1.91478335]),
#  'rank_test_score': array([ 7,  9, 13, 10,  5, 18, 15, 16,  3, 19, 11, 22,  1, 17,  8, 23,  4,
#         20, 14, 21,  2, 12,  6, 24])}

# %%
svr_re = svr_grid.cv_results_

dt_re = dt_grid.cv_results_

rf_re = rf_grid.cv_results_

# table = pd.DataFrame.from_dict(re)
# table

# %%
svr_re
# Out:
# {'mean_fit_time': array([0.17552934, 0.13603578, 0.11289763, 0.16435976, 0.29401307,
#         0.14122143, 0.12207351, 0.15139484, 0.65225506, 0.13803148,
#         0.14102249, 0.14899902, 1.03383489, 0.14321585, 0.17273836,
#         0.16115975, 0.53676505, 0.17154217, 0.15837626, 0.17213945,
#         3.16913705, 0.17732601, 0.29660602, 0.16376376]),
#  'std_fit_time': array([0.0270719 , 0.01209295, 0.00336003, 0.00798849, 0.01039148,
#         0.00737172, 0.00371067, 0.00603048, 0.07869215, 0.00569778,
#         0.00723538, 0.00162049, 0.10983066, 0.00663003, 0.00973749,
#         0.01101185, 0.23593144, 0.02520707, 0.01222007, 0.00678233,
#         0.52797327, 0.01801247, 0.0552434 , 0.00820581]),
#  'mean_score_time': array([0.02134447, 0.07021232, 0.01974735, 0.03550763, 0.01914959,
#         0.070612  , 0.01934829, 0.03291225, 0.01795502, 0.06782312,
#         0.01895046, 0.0341095 , 0.01855111, 0.06941419, 0.0195477 ,
#         0.03271461, 0.02413535, 0.08178163, 0.02094393, 0.03789983,
#         0.01635504, 0.07719407, 0.0221416 , 0.03689971]),
#  'std_score_time': array([0.0060685 , 0.00205373, 0.00193392, 0.00376356, 0.0014661 ,
#         0.00247547, 0.00149308, 0.00063037, 0.00209574, 0.0043195 ,
#         0.00109141, 0.00425037, 0.00257027, 0.00354522, 0.00135444,
#         0.00212927, 0.00765791, 0.00862516, 0.00227418, 0.00467944,
#         0.00337698, 0.00396923, 0.00533022, 0.00388824]),
#  'param_C': masked_array(data=[10, 10, 10, 10, 100, 100, 100, 100, 500, 500, 500, 500,
#                     1000, 1000, 1000, 1000, 200, 200, 200, 200, 3000, 3000,
#                     3000, 3000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['linear', 'rbf', 'poly', 'sigmoid', 'linear', 'rbf',
#                     'poly', 'sigmoid', 'linear', 'rbf', 'poly', 'sigmoid',
#                     'linear', 'rbf', 'poly', 'sigmoid', 'linear', 'rbf',
#                     'poly', 'sigmoid', 'linear', 'rbf', 'poly', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'poly'},
#   {'C': 10, 'kernel': 'sigmoid'},
#   {'C': 100, 'kernel': 'linear'},
#   {'C': 100, 'kernel': 'rbf'},
#   {'C': 100, 'kernel': 'poly'},
#   {'C': 100, 'kernel': 'sigmoid'},
#   {'C': 500, 'kernel': 'linear'},
#   {'C': 500, 'kernel': 'rbf'},
#   {'C': 500, 'kernel': 'poly'},
#   {'C': 500, 'kernel': 'sigmoid'},
#   {'C': 1000, 'kernel': 'linear'},
#   {'C': 1000, 'kernel': 'rbf'},
#   {'C': 1000, 'kernel': 'poly'},
#   {'C': 1000, 'kernel': 'sigmoid'},
#   {'C': 200, 'kernel': 'linear'},
#   {'C': 200, 'kernel': 'rbf'},
#   {'C': 200, 'kernel': 'poly'},
#   {'C': 200, 'kernel': 'sigmoid'},
#   {'C': 3000, 'kernel': 'linear'},
#   {'C': 3000, 'kernel': 'rbf'},
#   {'C': 3000, 'kernel': 'poly'},
#   {'C': 3000, 'kernel': 'sigmoid'}],
#  'split0_test_score': array([ -0.0189429 ,  -0.11040913,  -0.12515269,  -0.11674324,
#           0.55931297,  -0.16018172,  -0.13288461,  -0.14245497,
#           0.63213476,  -0.16091649,  -0.11199451,  -0.59087785,
#           0.7363985 ,  -0.15543029,  -0.0805268 ,  -2.04313994,
#           0.59754018,  -0.16437403,  -0.12863679,  -0.19990884,
#           0.67777829,  -0.12895834,   0.03769959, -15.56185339]),
#  'split1_test_score': array([  0.02988647,  -0.09745886,  -0.08150541,  -0.11931157,
#           0.52179776,  -0.10725311,  -0.08246084,  -0.16083065,
#           0.58719506,  -0.10351408,  -0.06145466,  -0.75976455,
#           0.6751618 ,  -0.09826656,  -0.02846903,  -2.68612062,
#           0.55753768,  -0.10642599,  -0.07846791,  -0.23183623,
#           0.62681429,  -0.07557819,   0.0984962 , -20.49890817]),
#  'split2_test_score': array([  0.02216742,  -0.07448755,  -0.11190705,  -0.08521385,
#           0.5476908 ,  -0.12343034,  -0.12921953,  -0.1175443 ,
#           0.61909515,  -0.12831196,  -0.10594393,  -0.60933322,
#           0.68000238,  -0.12372356,  -0.07337624,  -2.19456334,
#           0.58678115,  -0.12906536,  -0.12500339,  -0.18018945,
#           0.73280574,  -0.10019878,   0.0492908 , -17.09547395]),
#  'split3_test_score': array([ 3.11150946e-03, -9.95972567e-02, -1.31602268e-01, -1.08210107e-01,
#          5.38804573e-01, -1.37753025e-01, -1.39961828e-01, -1.37983588e-01,
#          6.10472426e-01, -1.39322912e-01, -1.18600125e-01, -6.19829956e-01,
#          6.99376769e-01, -1.37136880e-01, -8.66105151e-02, -2.21085823e+00,
#          5.74763963e-01, -1.41840863e-01, -1.35483801e-01, -2.02001312e-01,
#          6.33478783e-01, -1.16051182e-01,  3.56153469e-02, -1.67508766e+01]),
#  'split4_test_score': array([ -0.06665348,  -0.12442819,  -0.17932768,  -0.10871636,
#           0.50851762,  -0.20955111,  -0.1892193 ,  -0.13040193,
#           0.58949358,  -0.21314497,  -0.16416545,  -0.53924566,
#           0.67795161,  -0.20640524,  -0.13449284,  -1.94252105,
#           0.55542032,  -0.21644483,  -0.18291868,  -0.18095347,
#           0.69869163,  -0.17930409,  -0.02092444, -15.01216755]),
#  'mean_test_score': array([-6.08619573e-03, -1.01276198e-01, -1.25899020e-01, -1.07639026e-01,
#          5.35224744e-01, -1.47633859e-01, -1.34749222e-01, -1.37843088e-01,
#          6.07678194e-01, -1.49042083e-01, -1.12431736e-01, -6.23810245e-01,
#          6.93778210e-01, -1.44192505e-01, -8.06950833e-02, -2.21544064e+00,
#          5.74408659e-01, -1.51630214e-01, -1.30102114e-01, -1.98977860e-01,
#          6.73913747e-01, -1.20018118e-01,  4.00354972e-02, -1.69838559e+01]),
#  'std_test_score': array([0.03467157, 0.01645872, 0.03179394, 0.01202922, 0.01812189,
#         0.03551124, 0.03394787, 0.01426274, 0.01724249, 0.03700589,
#         0.03272727, 0.07340942, 0.02295499, 0.036262  , 0.03379451,
#         0.25540914, 0.0163307 , 0.037448  , 0.03320478, 0.01880193,
#         0.03987603, 0.03457804, 0.03806422, 1.91478335]),
#  'rank_test_score': array([ 7,  9, 13, 10,  5, 18, 15, 16,  3, 19, 11, 22,  1, 17,  8, 23,  4,
#         20, 14, 21,  2, 12,  6, 24])}

# %%
dt_re
# Out:
# {'mean_fit_time': array([0.01057138, 0.01076946, 0.00957198, 0.00658355, 0.00837374,
#         0.00757899, 0.01037192, 0.00757494, 0.0097703 , 0.00953383,
#         0.01057053, 0.00841908, 0.0478724 , 0.03470659, 0.02612886,
#         0.02154169, 0.02931929, 0.02174177, 0.01495972, 0.01196666,
#         0.01396222, 0.01256862, 0.01276555, 0.00997229]),
#  'std_fit_time': array([0.00119655, 0.00212915, 0.00135309, 0.00048996, 0.00101189,
#         0.00101867, 0.0004894 , 0.00080046, 0.00425123, 0.00384348,
#         0.00386675, 0.00230852, 0.00189178, 0.0027781 , 0.00159596,
#         0.00135285, 0.00381497, 0.00171578, 0.00063052, 0.00109328,
#         0.0016677 , 0.00101335, 0.00074633, 0.00218429]),
#  'mean_score_time': array([0.00418935, 0.00499187, 0.00439043, 0.00598502, 0.00678105,
#         0.00498981, 0.00519037, 0.00458956, 0.00638275, 0.00518227,
#         0.01021652, 0.00474577, 0.00398903, 0.00418963, 0.00518732,
#         0.00438886, 0.00538783, 0.00459094, 0.003793  , 0.00438886,
#         0.00379057, 0.00398812, 0.00399327, 0.00339203]),
#  'std_score_time': array([0.00039978, 0.00252318, 0.00048875, 0.00260084, 0.00239382,
#         0.00088968, 0.00146526, 0.0007984 , 0.00135271, 0.0034226 ,
#         0.0044354 , 0.00116018, 0.00062977, 0.00116391, 0.00132406,
#         0.00135341, 0.00149394, 0.00161961, 0.00039447, 0.0014933 ,
#         0.00039957, 0.00063175, 0.0006304 , 0.00079838]),
#  'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'squared_error', 'squared_error',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                     'poisson'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[None, None, 'sqrt', 'sqrt', 'log2', 'log2', None, None,
#                     'sqrt', 'sqrt', 'log2', 'log2', None, None, 'sqrt',
#                     'sqrt', 'log2', 'log2', None, None, 'sqrt', 'sqrt',
#                     'log2', 'log2'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_splitter': masked_array(data=['best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'random'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'squared_error',
#    'max_features': None,
#    'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': None, 'splitter': 'random'},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': None, 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': None, 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'best'},
#   {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'absolute_error',
#    'max_features': 'sqrt',
#    'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'absolute_error',
#    'max_features': 'log2',
#    'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': None, 'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'random'}],
#  'split0_test_score': array([0.72905852, 0.70413999, 0.71867124, 0.58700845, 0.75887846,
#         0.74594984, 0.71765746, 0.66755475, 0.6912886 , 0.71424584,
#         0.70507078, 0.62801891, 0.73116747, 0.68889188, 0.65765348,
#         0.65926661, 0.69174526, 0.63777647, 0.74337165, 0.70950366,
#         0.76448125, 0.74638986, 0.78562261, 0.75078601]),
#  'split1_test_score': array([0.64283754, 0.60381142, 0.50513984, 0.57793773, 0.57030107,
#         0.62679416, 0.65164934, 0.61906339, 0.41123143, 0.55739234,
#         0.59423508, 0.52663709, 0.59004975, 0.63232752, 0.62767902,
#         0.62215855, 0.657294  , 0.43197464, 0.65770514, 0.63551826,
#         0.61152691, 0.44460998, 0.62664257, 0.58742661]),
#  'split2_test_score': array([0.74204026, 0.75293096, 0.72614805, 0.72332713, 0.67792133,
#         0.56948278, 0.74459359, 0.71630953, 0.7007031 , 0.69064777,
#         0.56655337, 0.68365209, 0.7021971 , 0.72852104, 0.71032164,
#         0.68893127, 0.70346047, 0.6023529 , 0.73249235, 0.70522217,
#         0.62334142, 0.48793849, 0.69332233, 0.66293082]),
#  'split3_test_score': array([0.72806512, 0.75531552, 0.67512151, 0.73465832, 0.69840235,
#         0.64371084, 0.73835054, 0.71688789, 0.72468873, 0.63752322,
#         0.63698228, 0.64597886, 0.73002255, 0.72874567, 0.74562852,
#         0.66097842, 0.58450123, 0.56204749, 0.72489865, 0.69032366,
#         0.62446563, 0.63045959, 0.69241982, 0.70819533]),
#  'split4_test_score': array([0.68294611, 0.69103729, 0.697109  , 0.62894376, 0.67812125,
#         0.64055182, 0.68571158, 0.77193339, 0.68157465, 0.65629134,
#         0.72262106, 0.67516219, 0.76879251, 0.71943507, 0.58750584,
#         0.64479765, 0.54416593, 0.69586638, 0.68601191, 0.74702529,
#         0.70833042, 0.5850614 , 0.72634406, 0.62576245]),
#  'mean_test_score': array([0.70498951, 0.70144704, 0.66443793, 0.65037508, 0.67672489,
#         0.64529789, 0.7075925 , 0.69834979, 0.6418973 , 0.6512201 ,
#         0.64509252, 0.63188983, 0.70444588, 0.69958423, 0.6657577 ,
#         0.6552265 , 0.63623338, 0.58600358, 0.70889594, 0.69751861,
#         0.66642913, 0.57889186, 0.70487028, 0.66702025]),
#  'std_test_score': array([0.03696847, 0.05513753, 0.08161717, 0.06655444, 0.06090736,
#         0.05700206, 0.03471268, 0.05160509, 0.11621796, 0.05393284,
#         0.06071033, 0.05629112, 0.06099218, 0.03665945, 0.05657616,
#         0.02185255, 0.06196327, 0.08867511, 0.03207999, 0.03619312,
#         0.06000279, 0.10682417, 0.05174941, 0.05790711]),
#  'rank_test_score': array([ 3,  6, 14, 17, 10, 18,  2,  8, 20, 16, 19, 22,  5,  7, 13, 15, 21,
#         23,  1,  9, 12, 24,  4, 11])}

# %%
rf_re
# Out:
# {'mean_fit_time': array([0.07141008, 0.63709645, 0.05624876, 0.4739327 , 0.05345516,
#         0.48250585, 0.07140975, 0.63869138, 0.05604844, 0.48569884,
#         0.05465288, 0.47592673, 0.2708745 , 2.82385077, 0.15358744,
#         1.70464339, 0.17456069, 1.60769958, 0.10392127, 1.01847792,
#         0.0885622 , 0.84613881, 0.09035745, 0.78729248]),
#  'std_fit_time': array([0.00421289, 0.01116673, 0.00606976, 0.00525444, 0.00162084,
#         0.01413549, 0.00184936, 0.00953556, 0.00329937, 0.0139633 ,
#         0.00375322, 0.00818536, 0.01049203, 0.12838854, 0.00531351,
#         0.13542258, 0.00739911, 0.02702383, 0.00420325, 0.01532578,
#         0.00477947, 0.01353913, 0.00573305, 0.08689907]),
#  'mean_score_time': array([0.00798149, 0.02413564, 0.00638375, 0.0205451 , 0.00678329,
#         0.02293983, 0.00618262, 0.0219389 , 0.00638537, 0.02234063,
#         0.00638361, 0.02214074, 0.00558558, 0.02054744, 0.00578518,
#         0.02034655, 0.00894837, 0.01934853, 0.00758114, 0.02439942,
#         0.00698466, 0.02692828, 0.00598459, 0.0211452 ]),
#  'std_score_time': array([0.00356573, 0.00270577, 0.00101736, 0.00135359, 0.00132361,
#         0.0020924 , 0.00116472, 0.00062925, 0.00101748, 0.00101718,
#         0.00184954, 0.00291843, 0.00119679, 0.00162213, 0.00097747,
#         0.00162258, 0.00231172, 0.00101697, 0.00135248, 0.00268498,
#         0.00178905, 0.01149669, 0.00089207, 0.00443319]),
#  'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'squared_error', 'squared_error',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                     'poisson'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[None, None, 'sqrt', 'sqrt', 'log2', 'log2', None, None,
#                     'sqrt', 'sqrt', 'log2', 'log2', None, None, 'sqrt',
#                     'sqrt', 'log2', 'log2', None, None, 'sqrt', 'sqrt',
#                     'log2', 'log2'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[10, 100, 10, 100, 10, 100, 10, 100, 10, 100, 10, 100,
#                     10, 100, 10, 100, 10, 100, 10, 100, 10, 100, 10, 100],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'params': [{'criterion': 'squared_error',
#    'max_features': None,
#    'n_estimators': 10},
#   {'criterion': 'squared_error', 'max_features': None, 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'friedman_mse', 'max_features': None, 'n_estimators': 10},
#   {'criterion': 'friedman_mse', 'max_features': None, 'n_estimators': 100},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_features': None, 'n_estimators': 10},
#   {'criterion': 'absolute_error', 'max_features': None, 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': None, 'n_estimators': 10},
#   {'criterion': 'poisson', 'max_features': None, 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}],
#  'split0_test_score': array([0.8475734 , 0.84757549, 0.84186872, 0.85971657, 0.84110731,
#         0.85732995, 0.83597367, 0.84487856, 0.85082011, 0.86233154,
#         0.83614157, 0.85638476, 0.82665023, 0.83277404, 0.84461196,
#         0.85354694, 0.83506028, 0.85795182, 0.83613098, 0.85473532,
#         0.84986121, 0.85620583, 0.83293313, 0.8608645 ]),
#  'split1_test_score': array([0.75221987, 0.7700043 , 0.76119045, 0.780065  , 0.7599302 ,
#         0.77990372, 0.77236918, 0.77280851, 0.76663726, 0.77824219,
#         0.76526475, 0.77667085, 0.72995284, 0.76746663, 0.76508043,
#         0.78630436, 0.74952832, 0.7815552 , 0.76844827, 0.7728424 ,
#         0.76027164, 0.77700007, 0.7770904 , 0.77380963]),
#  'split2_test_score': array([0.86980119, 0.85667192, 0.8505105 , 0.86261018, 0.80506647,
#         0.86096354, 0.85368033, 0.85576579, 0.84472746, 0.86442578,
#         0.85341886, 0.86140088, 0.84046997, 0.85701213, 0.82623601,
#         0.85918235, 0.83511587, 0.86245862, 0.85463057, 0.85942037,
#         0.84181568, 0.861322  , 0.85195129, 0.86464888]),
#  'split3_test_score': array([0.81685955, 0.81716842, 0.81675713, 0.83120497, 0.80869655,
#         0.82809145, 0.81338352, 0.81551718, 0.81733368, 0.83034545,
#         0.81523007, 0.82754913, 0.80831724, 0.82322988, 0.8173414 ,
#         0.8272177 , 0.81907636, 0.82795714, 0.79571515, 0.81681642,
#         0.80478937, 0.82816764, 0.81011963, 0.83125292]),
#  'split4_test_score': array([0.82917499, 0.83648181, 0.82201582, 0.83397367, 0.82301443,
#         0.83404641, 0.83048287, 0.83110077, 0.81445759, 0.83997759,
#         0.82023418, 0.84002194, 0.81664748, 0.835768  , 0.83875416,
#         0.84105841, 0.83817805, 0.83905201, 0.8326536 , 0.83729899,
#         0.82495449, 0.83485215, 0.82261199, 0.84055559]),
#  'mean_test_score': array([0.8231258 , 0.82558039, 0.81846852, 0.83351408, 0.80756299,
#         0.83206701, 0.82117791, 0.82401416, 0.81879522, 0.83506451,
#         0.81805789, 0.83240551, 0.80440755, 0.82325013, 0.81840479,
#         0.83346195, 0.81539178, 0.83379496, 0.81751571, 0.8282227 ,
#         0.81633848, 0.83150954, 0.81894129, 0.8342263 ]),
#  'std_test_score': array([0.03969833, 0.03075312, 0.03121073, 0.02964962, 0.02698284,
#         0.02903087, 0.02758604, 0.02894107, 0.02979758, 0.03124343,
#         0.02958806, 0.03034364, 0.03873975, 0.02999691, 0.02830851,
#         0.02602107, 0.03360558, 0.02896849, 0.03110008, 0.03148229,
#         0.0320124 , 0.02997437, 0.02501289, 0.03266252]),
#  'rank_test_score': array([13, 10, 17,  4, 23,  7, 14, 11, 16,  1, 19,  6, 24, 12, 18,  5, 22,
#          3, 20,  9, 21,  8, 15,  2])}

# %%
svr_table = pd.DataFrame.from_dict(svr_re)
svr_table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.175529      0.027072         0.021344        0.006069       10
# 1        0.136036      0.012093         0.070212        0.002054       10
# 2        0.112898      0.003360         0.019747        0.001934       10
# 3        0.164360      0.007988         0.035508        0.003764       10
# 4        0.294013      0.010391         0.019150        0.001466      100
# 5        0.141221      0.007372         0.070612        0.002475      100
# 6        0.122074      0.003711         0.019348        0.001493      100
# 7        0.151395      0.006030         0.032912        0.000630      100
# 8        0.652255      0.078692         0.017955        0.002096      500
# 9        0.138031      0.005698         0.067823        0.004320      500
# 10       0.141022      0.007235         0.018950        0.001091      500
# 11       0.148999      0.001620         0.034109        0.004250      500
# 12       1.033835      0.109831         0.018551        0.002570     1000
# 13       0.143216      0.006630         0.069414        0.003545     1000
# 14       0.172738      0.009737         0.019548        0.001354     1000
# 15       0.161160      0.011012         0.032715        0.002129     1000
# 16       0.536765      0.235931         0.024135        0.007658      200
# 17       0.171542      0.025207         0.081782        0.008625      200
# 18       0.158376      0.012220         0.020944        0.002274      200
# 19       0.172139      0.006782         0.037900        0.004679      200
# 20       3.169137      0.527973         0.016355        0.003377     3000
# 21       0.177326      0.018012         0.077194        0.003969     3000
# 22       0.296606      0.055243         0.022142        0.005330     3000
# 23       0.163764      0.008206         0.036900        0.003888     3000
#
#    param_kernel                            params  split0_test_score  \
# 0        linear     {'C': 10, 'kernel': 'linear'}          -0.018943
# 1           rbf        {'C': 10, 'kernel': 'rbf'}          -0.110409
# 2          poly       {'C': 10, 'kernel': 'poly'}          -0.125153
# 3       sigmoid    {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 4        linear    {'C': 100, 'kernel': 'linear'}           0.559313
# 5           rbf       {'C': 100, 'kernel': 'rbf'}          -0.160182
# 6          poly      {'C': 100, 'kernel': 'poly'}          -0.132885
# 7       sigmoid   {'C': 100, 'kernel': 'sigmoid'}          -0.142455
# 8        linear    {'C': 500, 'kernel': 'linear'}           0.632135
# 9           rbf       {'C': 500, 'kernel': 'rbf'}          -0.160916
# 10         poly      {'C': 500, 'kernel': 'poly'}          -0.111995
# 11      sigmoid   {'C': 500, 'kernel': 'sigmoid'}          -0.590878
# 12       linear   {'C': 1000, 'kernel': 'linear'}           0.736398
# 13          rbf      {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 14         poly     {'C': 1000, 'kernel': 'poly'}          -0.080527
# 15      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}          -2.043140
# 16       linear    {'C': 200, 'kernel': 'linear'}           0.597540
# 17          rbf       {'C': 200, 'kernel': 'rbf'}          -0.164374
# 18         poly      {'C': 200, 'kernel': 'poly'}          -0.128637
# 19      sigmoid   {'C': 200, 'kernel': 'sigmoid'}          -0.199909
# 20       linear   {'C': 3000, 'kernel': 'linear'}           0.677778
# 21          rbf      {'C': 3000, 'kernel': 'rbf'}          -0.128958
# 22         poly     {'C': 3000, 'kernel': 'poly'}           0.037700
# 23      sigmoid  {'C': 3000, 'kernel': 'sigmoid'}         -15.561853
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.029886           0.022167           0.003112
# 1           -0.097459          -0.074488          -0.099597
# 2           -0.081505          -0.111907          -0.131602
# 3           -0.119312          -0.085214          -0.108210
# 4            0.521798           0.547691           0.538805
# 5           -0.107253          -0.123430          -0.137753
# 6           -0.082461          -0.129220          -0.139962
# 7           -0.160831          -0.117544          -0.137984
# 8            0.587195           0.619095           0.610472
# 9           -0.103514          -0.128312          -0.139323
# 10          -0.061455          -0.105944          -0.118600
# 11          -0.759765          -0.609333          -0.619830
# 12           0.675162           0.680002           0.699377
# 13          -0.098267          -0.123724          -0.137137
# 14          -0.028469          -0.073376          -0.086611
# 15          -2.686121          -2.194563          -2.210858
# 16           0.557538           0.586781           0.574764
# 17          -0.106426          -0.129065          -0.141841
# 18          -0.078468          -0.125003          -0.135484
# 19          -0.231836          -0.180189          -0.202001
# 20           0.626814           0.732806           0.633479
# 21          -0.075578          -0.100199          -0.116051
# 22           0.098496           0.049291           0.035615
# 23         -20.498908         -17.095474         -16.750877
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.066653        -0.006086        0.034672                7
# 1           -0.124428        -0.101276        0.016459                9
# 2           -0.179328        -0.125899        0.031794               13
# 3           -0.108716        -0.107639        0.012029               10
# 4            0.508518         0.535225        0.018122                5
# 5           -0.209551        -0.147634        0.035511               18
# 6           -0.189219        -0.134749        0.033948               15
# 7           -0.130402        -0.137843        0.014263               16
# 8            0.589494         0.607678        0.017242                3
# 9           -0.213145        -0.149042        0.037006               19
# 10          -0.164165        -0.112432        0.032727               11
# 11          -0.539246        -0.623810        0.073409               22
# 12           0.677952         0.693778        0.022955                1
# 13          -0.206405        -0.144193        0.036262               17
# 14          -0.134493        -0.080695        0.033795                8
# 15          -1.942521        -2.215441        0.255409               23
# 16           0.555420         0.574409        0.016331                4
# 17          -0.216445        -0.151630        0.037448               20
# 18          -0.182919        -0.130102        0.033205               14
# 19          -0.180953        -0.198978        0.018802               21
# 20           0.698692         0.673914        0.039876                2
# 21          -0.179304        -0.120018        0.034578               12
# 22          -0.020924         0.040035        0.038064                6
# 23         -15.012168       -16.983856        1.914783               24

# %%
dt_table = pd.DataFrame.from_dict(dt_re)
dt_table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.010571      0.001197         0.004189        0.000400
# 1        0.010769      0.002129         0.004992        0.002523
# 2        0.009572      0.001353         0.004390        0.000489
# 3        0.006584      0.000490         0.005985        0.002601
# 4        0.008374      0.001012         0.006781        0.002394
# 5        0.007579      0.001019         0.004990        0.000890
# 6        0.010372      0.000489         0.005190        0.001465
# 7        0.007575      0.000800         0.004590        0.000798
# 8        0.009770      0.004251         0.006383        0.001353
# 9        0.009534      0.003843         0.005182        0.003423
# 10       0.010571      0.003867         0.010217        0.004435
# 11       0.008419      0.002309         0.004746        0.001160
# 12       0.047872      0.001892         0.003989        0.000630
# 13       0.034707      0.002778         0.004190        0.001164
# 14       0.026129      0.001596         0.005187        0.001324
# 15       0.021542      0.001353         0.004389        0.001353
# 16       0.029319      0.003815         0.005388        0.001494
# 17       0.021742      0.001716         0.004591        0.001620
# 18       0.014960      0.000631         0.003793        0.000394
# 19       0.011967      0.001093         0.004389        0.001493
# 20       0.013962      0.001668         0.003791        0.000400
# 21       0.012569      0.001013         0.003988        0.000632
# 22       0.012766      0.000746         0.003993        0.000630
# 23       0.009972      0.002184         0.003392        0.000798
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               None           best
# 7     friedman_mse               None         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               None           best
# 13  absolute_error               None         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.729059
# 1   {'criterion': 'squared_error', 'max_features':...           0.704140
# 2   {'criterion': 'squared_error', 'max_features':...           0.718671
# 3   {'criterion': 'squared_error', 'max_features':...           0.587008
# 4   {'criterion': 'squared_error', 'max_features':...           0.758878
# 5   {'criterion': 'squared_error', 'max_features':...           0.745950
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.717657
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.667555
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.691289
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.714246
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.705071
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.628019
# 12  {'criterion': 'absolute_error', 'max_features'...           0.731167
# 13  {'criterion': 'absolute_error', 'max_features'...           0.688892
# 14  {'criterion': 'absolute_error', 'max_features'...           0.657653
# 15  {'criterion': 'absolute_error', 'max_features'...           0.659267
# 16  {'criterion': 'absolute_error', 'max_features'...           0.691745
# 17  {'criterion': 'absolute_error', 'max_features'...           0.637776
# 18  {'criterion': 'poisson', 'max_features': None,...           0.743372
# 19  {'criterion': 'poisson', 'max_features': None,...           0.709504
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.764481
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.746390
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.785623
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.750786
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.642838           0.742040           0.728065
# 1            0.603811           0.752931           0.755316
# 2            0.505140           0.726148           0.675122
# 3            0.577938           0.723327           0.734658
# 4            0.570301           0.677921           0.698402
# 5            0.626794           0.569483           0.643711
# 6            0.651649           0.744594           0.738351
# 7            0.619063           0.716310           0.716888
# 8            0.411231           0.700703           0.724689
# 9            0.557392           0.690648           0.637523
# 10           0.594235           0.566553           0.636982
# 11           0.526637           0.683652           0.645979
# 12           0.590050           0.702197           0.730023
# 13           0.632328           0.728521           0.728746
# 14           0.627679           0.710322           0.745629
# 15           0.622159           0.688931           0.660978
# 16           0.657294           0.703460           0.584501
# 17           0.431975           0.602353           0.562047
# 18           0.657705           0.732492           0.724899
# 19           0.635518           0.705222           0.690324
# 20           0.611527           0.623341           0.624466
# 21           0.444610           0.487938           0.630460
# 22           0.626643           0.693322           0.692420
# 23           0.587427           0.662931           0.708195
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.682946         0.704990        0.036968                3
# 1            0.691037         0.701447        0.055138                6
# 2            0.697109         0.664438        0.081617               14
# 3            0.628944         0.650375        0.066554               17
# 4            0.678121         0.676725        0.060907               10
# 5            0.640552         0.645298        0.057002               18
# 6            0.685712         0.707593        0.034713                2
# 7            0.771933         0.698350        0.051605                8
# 8            0.681575         0.641897        0.116218               20
# 9            0.656291         0.651220        0.053933               16
# 10           0.722621         0.645093        0.060710               19
# 11           0.675162         0.631890        0.056291               22
# 12           0.768793         0.704446        0.060992                5
# 13           0.719435         0.699584        0.036659                7
# 14           0.587506         0.665758        0.056576               13
# 15           0.644798         0.655227        0.021853               15
# 16           0.544166         0.636233        0.061963               21
# 17           0.695866         0.586004        0.088675               23
# 18           0.686012         0.708896        0.032080                1
# 19           0.747025         0.697519        0.036193                9
# 20           0.708330         0.666429        0.060003               12
# 21           0.585061         0.578892        0.106824               24
# 22           0.726344         0.704870        0.051749                4
# 23           0.625762         0.667020        0.057907               11

# %%
rf_table = pd.DataFrame.from_dict(rf_re)
rf_table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.071410      0.004213         0.007981        0.003566
# 1        0.637096      0.011167         0.024136        0.002706
# 2        0.056249      0.006070         0.006384        0.001017
# 3        0.473933      0.005254         0.020545        0.001354
# 4        0.053455      0.001621         0.006783        0.001324
# 5        0.482506      0.014135         0.022940        0.002092
# 6        0.071410      0.001849         0.006183        0.001165
# 7        0.638691      0.009536         0.021939        0.000629
# 8        0.056048      0.003299         0.006385        0.001017
# 9        0.485699      0.013963         0.022341        0.001017
# 10       0.054653      0.003753         0.006384        0.001850
# 11       0.475927      0.008185         0.022141        0.002918
# 12       0.270875      0.010492         0.005586        0.001197
# 13       2.823851      0.128389         0.020547        0.001622
# 14       0.153587      0.005314         0.005785        0.000977
# 15       1.704643      0.135423         0.020347        0.001623
# 16       0.174561      0.007399         0.008948        0.002312
# 17       1.607700      0.027024         0.019349        0.001017
# 18       0.103921      0.004203         0.007581        0.001352
# 19       1.018478      0.015326         0.024399        0.002685
# 20       0.088562      0.004779         0.006985        0.001789
# 21       0.846139      0.013539         0.026928        0.011497
# 22       0.090357      0.005733         0.005985        0.000892
# 23       0.787292      0.086899         0.021145        0.004433
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  10
# 1    squared_error               None                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6     friedman_mse               None                  10
# 7     friedman_mse               None                 100
# 8     friedman_mse               sqrt                  10
# 9     friedman_mse               sqrt                 100
# 10    friedman_mse               log2                  10
# 11    friedman_mse               log2                 100
# 12  absolute_error               None                  10
# 13  absolute_error               None                 100
# 14  absolute_error               sqrt                  10
# 15  absolute_error               sqrt                 100
# 16  absolute_error               log2                  10
# 17  absolute_error               log2                 100
# 18         poisson               None                  10
# 19         poisson               None                 100
# 20         poisson               sqrt                  10
# 21         poisson               sqrt                 100
# 22         poisson               log2                  10
# 23         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.847573
# 1   {'criterion': 'squared_error', 'max_features':...           0.847575
# 2   {'criterion': 'squared_error', 'max_features':...           0.841869
# 3   {'criterion': 'squared_error', 'max_features':...           0.859717
# 4   {'criterion': 'squared_error', 'max_features':...           0.841107
# 5   {'criterion': 'squared_error', 'max_features':...           0.857330
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.835974
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.844879
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.850820
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.862332
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.836142
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.856385
# 12  {'criterion': 'absolute_error', 'max_features'...           0.826650
# 13  {'criterion': 'absolute_error', 'max_features'...           0.832774
# 14  {'criterion': 'absolute_error', 'max_features'...           0.844612
# 15  {'criterion': 'absolute_error', 'max_features'...           0.853547
# 16  {'criterion': 'absolute_error', 'max_features'...           0.835060
# 17  {'criterion': 'absolute_error', 'max_features'...           0.857952
# 18  {'criterion': 'poisson', 'max_features': None,...           0.836131
# 19  {'criterion': 'poisson', 'max_features': None,...           0.854735
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.849861
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.856206
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.832933
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.860865
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.752220           0.869801           0.816860
# 1            0.770004           0.856672           0.817168
# 2            0.761190           0.850510           0.816757
# 3            0.780065           0.862610           0.831205
# 4            0.759930           0.805066           0.808697
# 5            0.779904           0.860964           0.828091
# 6            0.772369           0.853680           0.813384
# 7            0.772809           0.855766           0.815517
# 8            0.766637           0.844727           0.817334
# 9            0.778242           0.864426           0.830345
# 10           0.765265           0.853419           0.815230
# 11           0.776671           0.861401           0.827549
# 12           0.729953           0.840470           0.808317
# 13           0.767467           0.857012           0.823230
# 14           0.765080           0.826236           0.817341
# 15           0.786304           0.859182           0.827218
# 16           0.749528           0.835116           0.819076
# 17           0.781555           0.862459           0.827957
# 18           0.768448           0.854631           0.795715
# 19           0.772842           0.859420           0.816816
# 20           0.760272           0.841816           0.804789
# 21           0.777000           0.861322           0.828168
# 22           0.777090           0.851951           0.810120
# 23           0.773810           0.864649           0.831253
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.829175         0.823126        0.039698               13
# 1            0.836482         0.825580        0.030753               10
# 2            0.822016         0.818469        0.031211               17
# 3            0.833974         0.833514        0.029650                4
# 4            0.823014         0.807563        0.026983               23
# 5            0.834046         0.832067        0.029031                7
# 6            0.830483         0.821178        0.027586               14
# 7            0.831101         0.824014        0.028941               11
# 8            0.814458         0.818795        0.029798               16
# 9            0.839978         0.835065        0.031243                1
# 10           0.820234         0.818058        0.029588               19
# 11           0.840022         0.832406        0.030344                6
# 12           0.816647         0.804408        0.038740               24
# 13           0.835768         0.823250        0.029997               12
# 14           0.838754         0.818405        0.028309               18
# 15           0.841058         0.833462        0.026021                5
# 16           0.838178         0.815392        0.033606               22
# 17           0.839052         0.833795        0.028968                3
# 18           0.832654         0.817516        0.031100               20
# 19           0.837299         0.828223        0.031482                9
# 20           0.824954         0.816338        0.032012               21
# 21           0.834852         0.831510        0.029974                8
# 22           0.822612         0.818941        0.025013               15
# 23           0.840556         0.834226        0.032663                2

# %%
dt_res = dt_grid.predict([[24,25.5,0,1,0]])
dt_res
# Future_Prediction=grid.
# ,→predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])#␣
# ,→change the paramter,play with it.
# print("Future_Prediction={}".format(Future_Prediction))
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([2775.19215])
